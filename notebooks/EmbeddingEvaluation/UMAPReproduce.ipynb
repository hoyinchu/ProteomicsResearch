# %%
# Installs the umap dependency
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (2020.0.133)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (0.22.2.post1)
# Requirement already satisfied: numba!=0.47,>=0.46 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (0.48.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from umap-learn) (1.18.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20->umap-learn) (0.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba!=0.47,>=0.46->umap-learn) (46.1.3)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba!=0.47,>=0.46->umap-learn) (0.31.0)

# %%
import numpy as np
import pandas as pd

deleteome_csv_path = "/content/drive/My Drive/Colab Notebooks/Research/ProteinProteinAssociation/data_sources/deleteome_responsive_mutants_ex_wt_var_controls.txt"
deleteome_dataframe = pd.read_csv(deleteome_csv_path,delimiter='\t',skiprows=[1])
deleteome_dataframe.head()
# Out:
#    reporterId systematicName  ... wt-ypd vs. wt.1  wt-ypd vs. wt.2
# 0  SCAB000001          Q0010  ...       -0.029101         0.616744
# 1  SCAB000002          Q0017  ...       -0.012800         0.835180
# 2  SCAB000003          Q0032  ...       -0.007500         0.943031
# 3  SCAB000004          Q0045  ...       -0.160800         0.019957
# 4  SCAB000007          Q0060  ...       -0.891300         0.000000
#
# [5 rows x 2112 columns]

# %%
# Convert to numpy
deleteome_feature_matrix = deleteome_dataframe.iloc[:,3:-1].to_numpy()
print(deleteome_feature_matrix[0])
# Out:
# [ 5.8230566   0.03586317  0.813902   ...  0.91202     5.6007679
#  -0.02910071]

# %% [markdown]
# Defining UMAP parameters

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import umap

# Using the same parameters used in the paper
metric = 'cosine'
n_neighbors = 10
min_dist = 0.05
n_components = 2
reducer = umap.UMAP(n_neighbors=n_neighbors,
                    min_dist=min_dist,
                    n_components=n_components,
                    metric=metric)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Computes UMAP embedding (Takes about 30 seconds)

# %%
embedding = reducer.fit_transform(deleteome_feature_matrix)

# %%
print(embedding.shape)
print(embedding)
# Out:
# (6123, 2)
# [[14.126339   0.5566864]
#  [14.194224   0.5140868]
#  [14.078802   0.5717247]
#  ...
#  [ 9.743314  11.321952 ]
#  [ 8.171817   5.9310575]
#  [ 4.676471   8.482764 ]]

# %% [markdown]
# Plot the clusteres (Same color = Same cluster)

# %%
from sklearn.cluster import DBSCAN

clustering = DBSCAN(eps=0.5, min_samples=2).fit(embedding)
total_clusters = len(np.unique(clustering.labels_))

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(embedding[:,0], embedding[:,1], c=clustering.labels_)
plt.show()

def get_cluster(cluster_num:int):
  return embedding[np.where(clustering.labels_ == cluster_num)]

print("Number of Clusters: ")
print(total_clusters)
for i in range(total_clusters):
  print("Cluster {c_num}, number of genes: {g_num}".format(c_num=i,g_num=len(get_cluster(i))))
# Out:
# Number of Clusters:
# 10
# Cluster 0, number of genes: 902
# Cluster 1, number of genes: 4835
# Cluster 2, number of genes: 91
# Cluster 3, number of genes: 19
# Cluster 4, number of genes: 23
# Cluster 5, number of genes: 99
# Cluster 6, number of genes: 104
# Cluster 7, number of genes: 25
# Cluster 8, number of genes: 9
# Cluster 9, number of genes: 16

# %% [markdown]
# Check what complexes are in the Kemmeren Concensus

# %%
kemmeren_concensus_path = "/content/drive/My Drive/Colab Notebooks/Research/ProteinProteinAssociation/data_sources/Kemmeren_Consensus.csv"
kemmeren_concensus_dataframe = pd.read_csv(kemmeren_concensus_path)
kemmeren_concensus_dataframe.head()
# Out:
#             complex_name  ...              pubmed
# 0   Spp381-Prp38 complex  ...             9858581
# 1     Asf1-Rad53 complex  ...  11331602; 11172707
# 2      Pan1-End3 complex  ...             9234686
# 3  Sod1-Css1 heterodimer  ...            11101286
# 4         HAT-A4 complex  ...             9575221
#
# [5 rows x 8 columns]

# %% [markdown]
# Defining helper functions to check if any subsets of clusters are in the same complex

# %%
def get_cluster_genes(cluster_num:int):
  return deleteome_dataframe.iloc[np.where(clustering.labels_ == cluster_num)[0].tolist(),1].to_numpy()

from itertools import chain, combinations
# Returns a list of all subsets of size lower to upper (inclusive)
def get_all_subsets(iterable,lower,upper):
    s = list(iterable)
    return list(chain.from_iterable(combinations(s, r) for r in range(lower,upper+1)))

# Given a tuple, check if it is part of a complex 
def is_hit(subset):
  #print("Checking subset {s}".format(s=str(subset)))
  all_complexes = kemmeren_concensus_dataframe.iloc[:,2].to_numpy()
  for i in range(len(all_complexes)):
    hit_num = 0
    for j in range(len(subset)):
      if subset[j] in all_complexes[i]:
        hit_num += 1
    if (hit_num == len(subset)):
      print("{p} is a part of the {c_name} at row {row_num} with subunits {sub}".format(p=str(subset),c_name=kemmeren_concensus_dataframe.iloc[i,0],row_num=i,sub=kemmeren_concensus_dataframe.iloc[i,2]))
      return True
  return False

def check_cluster_with_subset_size(cluster_genes,subset_size):
  subsets = get_all_subsets(cluster_genes,subset_size,subset_size)
  print("Number of subsets of size {size} in this cluster: {num}".format(size=subset_size,num=len(subsets)))
  total_hits = 0
  for subset in subsets:
    if(is_hit(subset)):
      total_hits += 1
  print("Total subsets of size {size} hits: {num}".format(size=subset_size,num=total_hits))
  return total_hits

# %% [markdown]
# Case studies: Check if any subsets of size 2 hits in Cluster 4

# %%
cluster_4_genes = get_cluster_genes(4)
print("Total amount of genes in this cluster: {n}".format(n=len(cluster_4_genes)))
print()
cluster_4_genes_subset_2_total_hits = check_cluster_with_subset_size(cluster_4_genes,2)
# Size 2 Hit rate: 0.0118577075
print()
cluster_4_genes_subset_3_total_hits = check_cluster_with_subset_size(cluster_4_genes,3)
# Out:
# Total amount of genes in this cluster: 23
#
# Number of subsets of size 2 in this cluster: 253
# ('YHR005C', 'YJR086W') is a part of the heterotrimeric G-protein complex (GO) at row 439 with subunits YHR005C; YJR086W; YOR212W
# ('YHR005C', 'YOR212W') is a part of the heterotrimeric G-protein complex at row 127 with subunits YHR005C; YOR212W
# ('YJR086W', 'YOR212W') is a part of the heterotrimeric G-protein complex (GO) at row 439 with subunits YHR005C; YJR086W; YOR212W
# Total subsets of size 2 hits: 3
#
# Number of subsets of size 3 in this cluster: 1771
# ('YHR005C', 'YJR086W', 'YOR212W') is a part of the heterotrimeric G-protein complex (GO) at row 439 with subunits YHR005C; YJR086W; YOR212W
# Total subsets of size 3 hits: 1

# %% [markdown]
# Same with cluster 6

# %%
cluster_6_genes = get_cluster_genes(6)
print("Total amount of genes in this cluster: {n}".format(n=len(cluster_6_genes)))
# Hit rate: 0.00056011949
print()
cluster_6_genes_subset_2_total_hits = check_cluster_with_subset_size(cluster_6_genes,2)
# Out:
# Total amount of genes in this cluster: 104
#
# Number of subsets of size 2 in this cluster: 5356
# ('YBR109C', 'YOR326W') is a part of the putative Cmd1-Mlc1-Myo2-Myo1-Mlc2 complex at row 334 with subunits YBR109C; YGL106W; YOR326W; YHR023W; YPR188C
# ('YFL007W', 'YJL001W') is a part of the proteasome core complex at row 191 with subunits YFL007W; YER012W; YGL011C; YBL041W; YOL038W; YFR050C; YGR135W; YER094C; YJL001W; YOR362C; YPR103W; YGR253C; YML092C; YOR157C; YMR314W
# ('YHR039C-A', 'YOR332W') is a part of the vacuolar proton-transporting V-type ATPase, V1 domain at row 151 with subunits YJR033C; YDL185W; YBR127C; YGR020C; YHR039C-A; YEL051W; YPR036W; YOR332W; YKL080W
# Total subsets of size 2 hits: 3

# %% [markdown]
# Cluster 2

# %%
cluster_2_genes = get_cluster_genes(2)
print("Total amount of genes in this cluster: {n}".format(n=len(cluster_2_genes)))
print()
cluster_2_genes_subset_2_total_hits = check_cluster_with_subset_size(cluster_2_genes,2)
# Out:
# Total amount of genes in this cluster: 91
#
# Number of subsets of size 2 in this cluster: 4095
# ('YAL016W', 'YML109W') is a part of the protein phosphatase type 2A complex at row 110 with subunits YAL016W; YDL188C; YGL190C; YDL134C; YMR273C; YML109W; YOR014W
# ('YFL038C', 'YLR262C') is a part of the putative Gdi1-Ypt6-Ypt1 complex at row 383 with subunits YER136W; YLR262C; YFL038C
# Total subsets of size 2 hits: 2

# %%
# Control
all_unique_gene = np.unique(deleteome_dataframe.iloc[:,1].to_numpy())

def generate_pairs(total_pairs):
  to_return = []
  print("Sampling...")
  for row in np.random.choice(all_unique_gene,(total_pairs,2)):
    gene1 = row[0]
    gene2 = row[1]
    if gene1 == gene2:
      new_choices = np.random.choice(all_unique_gene,2,replace=False)
      gene1 = new_choices[0]
      gene2 = new_choices[1]
    to_return.append((gene1,gene2))
  return to_return

control_cluster = generate_pairs(100000)
control_total_hits = 0
for subset in control_cluster:
  if(is_hit(subset)):
    control_total_hits += 1
print("Total hit in control cluster of size {s}: {h}".format(s=len(control_cluster),h=control_total_hits))
# about 0.00051 hit rate
# Out:
# Sampling...
# ('YDR490C', 'YGR086C') is a part of the putative Pkh1-Mrp8-Pil1-Lsp1 complex at row 394 with subunits YDR490C; YKL142W; YGR086C; YPL004C
# ('YGL123W', 'YBL027W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YPR137W', 'YPL126W') is a part of the 90S preribosome at row 169 with subunits YBR247C; YDR324C; YPL126W; YOR310C; YGR145W; YLR222C; YNL075W; YJL109C; YDR398W; YCR057C; YPR144C; YLR409C; YNL132W; YLL011W; YDL148C; YOR145C; YBL004W; YLR186W; YCL059C; YJR145C; YDR449C; YPR112C; YMR128W; YJR002W; YDR299W; YOR096W; YPL217C; YLR197W; YOR078W; YDL014W; YPR137W; YMR093W; YOL010W; YPL266W; YLR003C; YJL069C; YGR128C; YLR129W; YGR090W; YPL012W; YER127W; YKR060W; YER082C; YEL055C; YDR064W; YHR196W; YGL171W; YHR148W
# ('YHL025W', 'YFL049W') is a part of the RSC complex at row 170 with subunits YMR091C; YGL013C; YNR023W; YHR056C; YLR357W; YML127W; YDR303C; YDR225W; YOR156C; YGR056W; YFR037C; YOR290C; YIL126W; YHL025W; YJL176C; YMR033W; YDR073W; YCR020W-B; YPR034W; YCR052W; YBR289W; YLR321C; YLR033W; YGR275W; YFL049W; YPL016W; YKR008W
# ('YDR449C', 'YDR064W') is a part of the 90S preribosome at row 169 with subunits YBR247C; YDR324C; YPL126W; YOR310C; YGR145W; YLR222C; YNL075W; YJL109C; YDR398W; YCR057C; YPR144C; YLR409C; YNL132W; YLL011W; YDL148C; YOR145C; YBL004W; YLR186W; YCL059C; YJR145C; YDR449C; YPR112C; YMR128W; YJR002W; YDR299W; YOR096W; YPL217C; YLR197W; YOR078W; YDL014W; YPR137W; YMR093W; YOL010W; YPL266W; YLR003C; YJL069C; YGR128C; YLR129W; YGR090W; YPL012W; YER127W; YKR060W; YER082C; YEL055C; YDR064W; YHR196W; YGL171W; YHR148W
# ('YMR047C', 'YER107C') is a part of the nucleoporin Nup82 subcomplex at row 73 with subunits YIL115C; YJL061W; YJL041W; YER107C; YMR047C
# ('YDR471W', 'YGL135W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YJL014W', 'YJL008C') is a part of the chaperonin-containing T-complex at row 215 with subunits YJL014W; YDL143W; YDR188W; YIL142W; YJL111W; YOR281C; YNL212W; YJL008C; YJR064W
# ('YDL029W', 'YKL013C') is a part of the Arp2-3 protein complex at row 172 with subunits YDL029W; YBR234C; YIL062C; YNR035C; YKL013C; YLR370C; YJR065C
# ('YHL004W', 'YKL155C') is a part of the mitochondrial small ribosomal subunit at row 122 with subunits YER050C; YNR037C; YBR251W; YGR215W; YBR146W; YPL118W; YMR158W; YDR036C; YGR084C; YDL045W-A; YHR059W; YDR041W; YGL129C; YPL013C; YKL155C; YIL093C; YNL137C; YDR337W; YJR101W; YJR113C; YBL090W; YMR188C; YNL081C; YDR175C; YOR158W; YHL004W; YDR347W; YNR036C; YNL306W; YGR165W; YKL003C
# ('YFL002C', 'YKR081C') is a part of the preribosome, large subunit precursor at row 203 with subunits YLL008W; YER006W; YPL211W; YBR142W; YNL061W; YNL110C; YOL077C; YDR496C; YHR052W; YMR290C; YKR081C; YLL034C; YOR272W; YKL172W; YPR016C; YDR087C; YGL111W; YHR088W; YLR002C; YFL002C; YKL009W; YCL054W; YDL031W; YPL093W; YOR206W; YLR449W; YMR049C; YNL002C; YMR229C; YGR103W
# ('YKL138C-A', 'YBR233W') is a part of the DASH complex at row 129 with subunits YDR201W; YDR016C; YKL052C; YGR113W; YGL061C; YKR083C; YKR037C; YKL138C-A; YBR233W-A
# ('YBR193C', 'YLR071C') is a part of the Srb-mediator complex at row 137 with subunits YBL093C; YDL005C; YGL127C; YCR081W; YGR104C; YDR308C; YER022W; YGL025C; YOL051W; YPR168W; YMR112C; YDR443C; YBR253W; YOL135C; YLR071C; YPL042C; YHR041C; YHR058C; YBR193C; YOR174W; YPR070W; YNR010W; YGL151W; YNL236W
# ('YGL048C', 'YFR052W') is a part of the proteasome regulatory particle at row 182 with subunits YDL147W; YHL030W; YDR363W-A; YFR010W; YGR232W; YDR394W; YER021W; YDR427W; YDL007W; YHR200W; YFR004W; YFR052W; YOR259C; YOR261C; YDL097C; YGL048C; YLR421C; YHR027C; YOR117W; YPR108W; YIL075C; YKL145W
# ('YOR096W', 'YPL012W') is a part of the 90S preribosome at row 169 with subunits YBR247C; YDR324C; YPL126W; YOR310C; YGR145W; YLR222C; YNL075W; YJL109C; YDR398W; YCR057C; YPR144C; YLR409C; YNL132W; YLL011W; YDL148C; YOR145C; YBL004W; YLR186W; YCL059C; YJR145C; YDR449C; YPR112C; YMR128W; YJR002W; YDR299W; YOR096W; YPL217C; YLR197W; YOR078W; YDL014W; YPR137W; YMR093W; YOL010W; YPL266W; YLR003C; YJL069C; YGR128C; YLR129W; YGR090W; YPL012W; YER127W; YKR060W; YER082C; YEL055C; YDR064W; YHR196W; YGL171W; YHR148W
# ('YNL282W', 'YGR030C') is a part of the ribonuclease MRP complex at row 128 with subunits YBL018C; YAL033W; YBR167C; YBR257W; YGR030C; YNL221C; YNL282W; YDR478W; YHR062C
# ('YMR229C', 'YHR052W') is a part of the preribosome, large subunit precursor at row 203 with subunits YLL008W; YER006W; YPL211W; YBR142W; YNL061W; YNL110C; YOL077C; YDR496C; YHR052W; YMR290C; YKR081C; YLL034C; YOR272W; YKL172W; YPR016C; YDR087C; YGL111W; YHR088W; YLR002C; YFL002C; YKL009W; YCL054W; YDL031W; YPL093W; YOR206W; YLR449W; YMR049C; YNL002C; YMR229C; YGR103W
# ('YJR042W', 'YGL100W') is a part of the nucleoporin Nup84 subcomplex at row 65 with subunits YGL100W; YDL116W; YGL092W; YKL057C; YJR042W; YLR208W
# ('YER021W', 'YHR027C') is a part of the proteasome regulatory particle at row 182 with subunits YDL147W; YHL030W; YDR363W-A; YFR010W; YGR232W; YDR394W; YER021W; YDR427W; YDL007W; YHR200W; YFR004W; YFR052W; YOR259C; YOR261C; YDL097C; YGL048C; YLR421C; YHR027C; YOR117W; YPR108W; YIL075C; YKL145W
# ('YJR033C', 'YDL185W') is a part of the vacuolar proton-transporting V-type ATPase, V1 domain at row 151 with subunits YJR033C; YDL185W; YBR127C; YGR020C; YHR039C-A; YEL051W; YPR036W; YOR332W; YKL080W
# ('YPL037C', 'YDR252W') is a part of the nascent polypeptide-associated complex at row 217 with subunits YHR193C; YPL037C; YDR252W
# ('YML071C', 'YGR120C') is a part of the Golgi transport complex at row 133 with subunits YNL041C; YPR105C; YGL005C; YGL223C; YER157W; YNL051W; YGR120C; YML071C
# ('YDL143W', 'YIL142W') is a part of the chaperonin-containing T-complex at row 215 with subunits YJL014W; YDL143W; YDR188W; YIL142W; YJL111W; YOR281C; YNL212W; YJL008C; YJR064W
# ('YJL069C', 'YDR299W') is a part of the 90S preribosome at row 169 with subunits YBR247C; YDR324C; YPL126W; YOR310C; YGR145W; YLR222C; YNL075W; YJL109C; YDR398W; YCR057C; YPR144C; YLR409C; YNL132W; YLL011W; YDL148C; YOR145C; YBL004W; YLR186W; YCL059C; YJR145C; YDR449C; YPR112C; YMR128W; YJR002W; YDR299W; YOR096W; YPL217C; YLR197W; YOR078W; YDL014W; YPR137W; YMR093W; YOL010W; YPL266W; YLR003C; YJL069C; YGR128C; YLR129W; YGR090W; YPL012W; YER127W; YKR060W; YER082C; YEL055C; YDR064W; YHR196W; YGL171W; YHR148W
# ('YLR117C', 'YLR424W') is a part of the spliceosome at row 408 with subunits YGL120C; YBR065C; YJR050W; YAL032C; YDR364C; YGR278W; YCR063W; YMR213W; YDL209C; YDR416W; YLL036C; YLR117C; YPL151C; YPR101W; YGL128C; YLR424W
# ('YBR114W', 'YNL230C') is a part of the Cul3-RING ubiquitin ligase complex (GO) at row 423 with subunits YBR114W; YGR003W; YJR052W; YNL230C; YPL046C
# ('YBR123C', 'YPL007C') is a part of the transcription factor TFIIIC complex at row 197 with subunits YGR047C; YAL001C; YDR362C; YBR123C; YOR110W; YPL007C
# ('YOL038W', 'YGR135W') is a part of the proteasome core complex at row 191 with subunits YFL007W; YER012W; YGL011C; YBL041W; YOL038W; YFR050C; YGR135W; YER094C; YJL001W; YOR362C; YPR103W; YGR253C; YML092C; YOR157C; YMR314W
# ('YIL018W', 'YPL249C-A') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YGR278W', 'YGL120C') is a part of the spliceosome at row 408 with subunits YGL120C; YBR065C; YJR050W; YAL032C; YDR364C; YGR278W; YCR063W; YMR213W; YDL209C; YDR416W; YLL036C; YLR117C; YPL151C; YPR101W; YGL128C; YLR424W
# ('YOL039W', 'YCR031C') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YDR471W', 'YBR191W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YKL180W', 'YGL103W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YLR197W', 'YLR129W') is a part of the 90S preribosome at row 169 with subunits YBR247C; YDR324C; YPL126W; YOR310C; YGR145W; YLR222C; YNL075W; YJL109C; YDR398W; YCR057C; YPR144C; YLR409C; YNL132W; YLL011W; YDL148C; YOR145C; YBL004W; YLR186W; YCL059C; YJR145C; YDR449C; YPR112C; YMR128W; YJR002W; YDR299W; YOR096W; YPL217C; YLR197W; YOR078W; YDL014W; YPR137W; YMR093W; YOL010W; YPL266W; YLR003C; YJL069C; YGR128C; YLR129W; YGR090W; YPL012W; YER127W; YKR060W; YER082C; YEL055C; YDR064W; YHR196W; YGL171W; YHR148W
# ('YMR049C', 'YPL211W') is a part of the preribosome, large subunit precursor at row 203 with subunits YLL008W; YER006W; YPL211W; YBR142W; YNL061W; YNL110C; YOL077C; YDR496C; YHR052W; YMR290C; YKR081C; YLL034C; YOR272W; YKL172W; YPR016C; YDR087C; YGL111W; YHR088W; YLR002C; YFL002C; YKL009W; YCL054W; YDL031W; YPL093W; YOR206W; YLR449W; YMR049C; YNL002C; YMR229C; YGR103W
# ('YER133W', 'YOR179C') is a part of the CPF complex at row 100 with subunits YMR061W; YER133W; YDR195W; YGR156W; YAL043C; YNL222W; YDR301W; YKL059C; YJR093C; YPR107C; YLR115W; YLR277C; YKR002W; YNL317W; YKL018W; YOR179C
# ('YDR418W', 'YOL039W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YHR165C', 'YDR473C') is a part of the U4-U6 x U5 tri-snRNP complex at row 124 with subunits YGR074W; YER029C; YLR147C; YLR275W; YER172C; YKL173W; YHR165C; YDL098C; YGR091W; YDR473C; YOR308C; YBR055C; YPR178W; YPR082C
# ('YOR340C', 'YOR341W') is a part of the RNA polymerase I complex at row 168 with subunits YNL113W; YPR110C; YHR143W-A; YBR154C; YPR187W; YOR224C; YOR210W; YDR156W; YJL148W; YJR063W; YNL248C; YOR340C; YOR341W; YPR010C
# ('YGL172W', 'YJL041W') is a part of the nucleoporin Nsp1 subcomplex at row 77 with subunits YFR002W; YGL172W; YGR119C; YJL041W
# ('YHR081W', 'YOR076C') is a part of the exosome (RNase complex) at row 228 with subunits YHR081W; YCR035C; YGR195W; YDL111C; YDR280W; YOR076C; YGR158C; YHR069C; YGR095C; YOL142W; YNL232W; YOL021C; YOR001W; YNR024W; YNL189W
# ('YGR090W', 'YLR223C') is a part of the CURI complex (GO) at row 424 with subunits YCL031C; YGR090W; YLR223C; YOR039W; YPR104C
# ('YML073C', 'YLR150W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YGR166W', 'YMR218C') is a part of the TRAPP complex at row 174 with subunits YGR166W; YKR068C; YOR115C; YDR108W; YDR246W; YML077W; YDR407C; YBR254C; YDR472W; YMR218C
# ('YMR231W', 'YPL045W') is a part of the HOPS complex at row 160 with subunits YMR231W; YAL002W; YLR396C; YLR148W; YDR080W; YDL077C; YPL045W
# ('YLL045C', 'YGL135W') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YNL290W', 'YBR087W') is a part of the Elg1 RFC-like complex at row 155 with subunits YBR087W; YOL094C; YNL290W; YJR068W; YOR217W; YOR144C
# ('YOL111C', 'YOR007C') is a part of the putative Ybr137w-Sgt2-Mdy2-Yor164c complex at row 321 with subunits YBR137W; YOR007C; YOL111C; YOR164C
# ('YGR056W', 'YKR008W') is a part of the RSC complex at row 170 with subunits YMR091C; YGL013C; YNR023W; YHR056C; YLR357W; YML127W; YDR303C; YDR225W; YOR156C; YGR056W; YFR037C; YOR290C; YIL126W; YHL025W; YJL176C; YMR033W; YDR073W; YCR020W-B; YPR034W; YCR052W; YBR289W; YLR321C; YLR033W; YGR275W; YFL049W; YPL016W; YKR008W
# ('YDR418W', 'YNL302C') is a part of the cytosolic large ribosomal subunit at row 218 with subunits YBL092W; YGL014W; YBR191W; YHR141C; YLR287C-A; YFR032C-A; YGR118W; YNL302C; YNL096C; YGL031C; YDR418W; YGL123W; YDR382W; YDL083C; YCR031C; YDR447C; YER074W; YBL027W; YDL136W; YHL001W; YJL177W; YGR034W; YMR194W; YKL180W; YBR181C; YOL040C; YHL033C; YFR031C-A; YNL069C; YML073C; YLR448W; YNL301C; YLR075W; YML063W; YLR441C; YJR123W; YNL178W; YPL090C; YLR150W; YGL147C; YBR031W; YGL030W; YDL075W; YGL103W; YDL082W; YDR471W; YMR242C; YOL127W; YGL135W; YGR085C; YIL133C; YLR029C; YDR012W; YOR312C; YGL076C; YLL045C; YOR063W; YPL198W; YPL249C-A; YLR340W; YIL018W; YPL220W; YMR142C; YOL039W
# ('YMR227C', 'YDR145W') is a part of the transcription factor TFIID complex at row 216 with subunits YBR198C; YDR167W; YDR145W; YMR236W; YGL112C; YGR274C; YMR227C; YML015C; YPL011C; YMR005W; YML098W
# Total hit in control cluster of size 100000: 51
